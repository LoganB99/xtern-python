# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %matplotlib inline

dataframe = pd.read_csv("scooters.csv")
x = dataframe.xcoordinate
y = dataframe.ycoordinate
size = dataframe.power_level
dataframe = dataframe.sort_values('scooter_id', ascending=False);

#g = sns.scatterplot(x="xcoordinate", y="ycoordinate",hue="power_level", data=dataframe0, palette=['green'], legend='full')

plt.scatter(x,y, s=(6-size), c=size, cmap="Oranges")

plt.show()
sns.kdeplot(x, y, cmap="Reds", shade=True)
plt.title('Overplotting? Try 2D density graph', loc='left')
# Out:
#        scooter_id  xcoordinate  ycoordinate  power_level
# 25667       25667     0.963641     1.300093            4
# 25666       25666     0.959825     1.297630            1
# 25665       25665     0.956886     1.286652            4
# 25664       25664     0.971847     1.282083            0
# 25663       25663     0.943601     1.292008            0
